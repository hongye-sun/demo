# %%
# !pip install -U --user pip
# Out:
# Collecting pip
#   Using cached https://files.pythonhosted.org/packages/00/b6/9cfa56b4081ad13874b0c6f96af8ce16cfbc1cb06bedf8e9164ce5551ec1/pip-19.3.1-py2.py3-none-any.whl
# Installing collected packages: pip
#   WARNING: The scripts pip, pip3 and pip3.5 are installed in '/home/jupyter/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed pip-19.3.1

# %%
# !pip install -U --user tfx
# Out:
# Requirement already up-to-date: tfx in ./.local/lib/python3.5/site-packages (0.15.0)
# Requirement already satisfied, skipping upgrade: jinja2<3,>=2.7.3 in /usr/local/lib/python3.5/dist-packages (from tfx) (2.10.3)
# Requirement already satisfied, skipping upgrade: tensorflow-transform<0.16,>=0.15 in ./.local/lib/python3.5/site-packages (from tfx) (0.15.0)
# Requirement already satisfied, skipping upgrade: ml-metadata<0.16,>=0.15.0rc0 in ./.local/lib/python3.5/site-packages (from tfx) (0.15.1)
# Requirement already satisfied, skipping upgrade: tfx-bsl<0.16,>=0.15.3 in ./.local/lib/python3.5/site-packages (from tfx) (0.15.3)
# Requirement already satisfied, skipping upgrade: six<2,>=1.10 in /usr/local/lib/python3.5/dist-packages (from tfx) (1.12.0)
# Requirement already satisfied, skipping upgrade: absl-py<0.9,>=0.1.6 in ./.local/lib/python3.5/site-packages (from tfx) (0.8.1)
# Requirement already satisfied, skipping upgrade: google-api-python-client<2,>=1.7.8 in /usr/local/lib/python3.5/dist-packages (from tfx) (1.7.11)
# Requirement already satisfied, skipping upgrade: tensorflow-model-analysis<0.16,>=0.15.2 in ./.local/lib/python3.5/site-packages (from tfx) (0.15.4)
# Requirement already satisfied, skipping upgrade: tensorflow-data-validation<0.16,>=0.15 in ./.local/lib/python3.5/site-packages (from tfx) (0.15.0)
# Requirement already satisfied, skipping upgrade: apache-beam[gcp]<3,>=2.16 in ./.local/lib/python3.5/site-packages (from tfx) (2.16.0)
# Requirement already satisfied, skipping upgrade: pyyaml<4,>=3.12 in ./.local/lib/python3.5/site-packages (from tfx) (3.13)
# Requirement already satisfied, skipping upgrade: tensorflow<3,>=1.15 in ./.local/lib/python3.5/site-packages (from tfx) (2.0.0)
# Requirement already satisfied, skipping upgrade: click<8,>=7 in /usr/local/lib/python3.5/dist-packages (from tfx) (7.0)
# Requirement already satisfied, skipping upgrade: protobuf<4,>=3.7 in /usr/local/lib/python3.5/dist-packages (from tfx) (3.10.0)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.5/dist-packages (from jinja2<3,>=2.7.3->tfx) (1.1.1)
# Requirement already satisfied, skipping upgrade: numpy<2,>=1.16 in ./.local/lib/python3.5/site-packages (from tensorflow-transform<0.16,>=0.15->tfx) (1.17.4)
# Requirement already satisfied, skipping upgrade: tensorflow-metadata<0.16,>=0.15 in ./.local/lib/python3.5/site-packages (from tensorflow-transform<0.16,>=0.15->tfx) (0.15.0)
# Requirement already satisfied, skipping upgrade: pydot<2,>=1.2 in /usr/local/lib/python3.5/dist-packages (from tensorflow-transform<0.16,>=0.15->tfx) (1.4.1)
# Requirement already satisfied, skipping upgrade: psutil<6,>=5.6 in /usr/local/lib/python3.5/dist-packages (from tfx-bsl<0.16,>=0.15.3->tfx) (5.6.3)
# Requirement already satisfied, skipping upgrade: tensorflow-serving-api<3,>=1.15 in ./.local/lib/python3.5/site-packages (from tfx-bsl<0.16,>=0.15.3->tfx) (2.0.0)
# Requirement already satisfied, skipping upgrade: pyarrow<0.15.0,>=0.14.0 in ./.local/lib/python3.5/site-packages (from tfx-bsl<0.16,>=0.15.3->tfx) (0.14.1)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.5/dist-packages (from google-api-python-client<2,>=1.7.8->tfx) (0.0.3)
# Requirement already satisfied, skipping upgrade: httplib2<1dev,>=0.9.2 in ./.local/lib/python3.5/site-packages (from google-api-python-client<2,>=1.7.8->tfx) (0.12.0)
# Requirement already satisfied, skipping upgrade: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.5/dist-packages (from google-api-python-client<2,>=1.7.8->tfx) (3.0.0)
# Requirement already satisfied, skipping upgrade: google-auth>=1.4.1 in /usr/local/lib/python3.5/dist-packages (from google-api-python-client<2,>=1.7.8->tfx) (1.6.3)
# Requirement already satisfied, skipping upgrade: scipy==1.1.0 in /usr/local/lib/python3.5/site-packages (from tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.1.0)
# Requirement already satisfied, skipping upgrade: jupyter<2,>=1 in /usr/local/lib/python3.5/dist-packages (from tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.0.0)
# Requirement already satisfied, skipping upgrade: ipywidgets<8,>=7 in /usr/local/lib/python3.5/dist-packages (from tensorflow-model-analysis<0.16,>=0.15.2->tfx) (7.5.1)
# Requirement already satisfied, skipping upgrade: ipython>=5 in /usr/local/lib/python3.5/dist-packages (from tensorflow-data-validation<0.16,>=0.15->tfx) (7.8.0)
# Requirement already satisfied, skipping upgrade: scikit-learn<0.22,>=0.18 in /usr/local/lib/python3.5/site-packages (from tensorflow-data-validation<0.16,>=0.15->tfx) (0.19.2)
# Requirement already satisfied, skipping upgrade: pandas<1,>=0.24 in /usr/local/lib/python3.5/dist-packages (from tensorflow-data-validation<0.16,>=0.15->tfx) (0.25.1)
# Requirement already satisfied, skipping upgrade: joblib<0.15,>=0.12 in /usr/local/lib/python3.5/dist-packages (from tensorflow-data-validation<0.16,>=0.15->tfx) (0.14.0)
# Requirement already satisfied, skipping upgrade: fastavro<0.22,>=0.21.4 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (0.21.24)
# Requirement already satisfied, skipping upgrade: oauth2client<4,>=2.0.1 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (3.0.0)
# Requirement already satisfied, skipping upgrade: dill<0.3.1,>=0.3.0 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (0.3.0)
# Requirement already satisfied, skipping upgrade: pymongo<4.0.0,>=3.8.0 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (3.9.0)
# Requirement already satisfied, skipping upgrade: avro-python3<2.0.0,>=1.8.1; python_version >= "3.0" in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.9.1)
# Requirement already satisfied, skipping upgrade: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.5/dist-packages (from apache-beam[gcp]<3,>=2.16->tfx) (2.8.0)
# Requirement already satisfied, skipping upgrade: hdfs<3.0.0,>=2.1.0 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (2.5.8)
# Requirement already satisfied, skipping upgrade: mock<3.0.0,>=1.0.1 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (2.0.0)
# Requirement already satisfied, skipping upgrade: pytz>=2018.3 in /usr/local/lib/python3.5/dist-packages (from apache-beam[gcp]<3,>=2.16->tfx) (2019.3)
# Requirement already satisfied, skipping upgrade: crcmod<2.0,>=1.7 in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.7)
# Requirement already satisfied, skipping upgrade: grpcio<2,>=1.12.1 in /usr/local/lib/python3.5/dist-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.24.1)
# Requirement already satisfied, skipping upgrade: future<1.0.0,>=0.16.0 in /usr/local/lib/python3.5/dist-packages (from apache-beam[gcp]<3,>=2.16->tfx) (0.18.1)
# Requirement already satisfied, skipping upgrade: google-cloud-core<2,>=0.28.1; extra == "gcp" in /usr/local/lib/python3.5/dist-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.0.3)
# Requirement already satisfied, skipping upgrade: google-cloud-pubsub<1.1.0,>=0.39.0; extra == "gcp" in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.0.2)
# Requirement already satisfied, skipping upgrade: google-cloud-bigtable<1.1.0,>=0.31.1; extra == "gcp" in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.0.0)
# Requirement already satisfied, skipping upgrade: cachetools<4,>=3.1.0; extra == "gcp" in /usr/local/lib/python3.5/dist-packages (from apache-beam[gcp]<3,>=2.16->tfx) (3.1.1)
# Requirement already satisfied, skipping upgrade: google-cloud-bigquery<1.18.0,>=1.6.0; extra == "gcp" in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.17.1)
# Requirement already satisfied, skipping upgrade: google-apitools<0.5.29,>=0.5.28; extra == "gcp" in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (0.5.28)
# Requirement already satisfied, skipping upgrade: google-cloud-datastore<1.8.0,>=1.7.1; extra == "gcp" in ./.local/lib/python3.5/site-packages (from apache-beam[gcp]<3,>=2.16->tfx) (1.7.4)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.5/dist-packages (from tensorflow<3,>=1.15->tfx) (1.11.2)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (1.1.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorflow<3,>=1.15->tfx) (0.29.0)
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (0.8.0)
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (1.0.8)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (0.2.2)
# Requirement already satisfied, skipping upgrade: tensorboard<2.1.0,>=2.0.0 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (2.0.1)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (3.1.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.1.0,>=2.0.0 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (2.0.1)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in ./.local/lib/python3.5/site-packages (from tensorflow<3,>=1.15->tfx) (0.1.8)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.5/dist-packages (from protobuf<4,>=3.7->tfx) (41.4.0)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos in /usr/local/lib/python3.5/dist-packages (from tensorflow-metadata<0.16,>=0.15->tensorflow-transform<0.16,>=0.15->tfx) (1.6.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.1.4 in /usr/local/lib/python3.5/dist-packages (from pydot<2,>=1.2->tensorflow-transform<0.16,>=0.15->tfx) (2.4.2)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.5/dist-packages (from google-auth>=1.4.1->google-api-python-client<2,>=1.7.8->tfx) (0.2.7)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /usr/local/lib/python3.5/dist-packages (from google-auth>=1.4.1->google-api-python-client<2,>=1.7.8->tfx) (4.0)
# Requirement already satisfied, skipping upgrade: intel-numpy in /usr/local/lib/python3.5/dist-packages (from scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.15.1)
# Requirement already satisfied, skipping upgrade: qtconsole in /usr/local/lib/python3.5/dist-packages (from jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (4.5.5)
# Requirement already satisfied, skipping upgrade: ipykernel in /usr/local/lib/python3.5/dist-packages (from jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (5.1.2)
# Requirement already satisfied, skipping upgrade: nbconvert in /usr/local/lib/python3.5/dist-packages (from jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (5.6.0)
# Requirement already satisfied, skipping upgrade: jupyter-console in /usr/local/lib/python3.5/dist-packages (from jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (6.0.0)
# Requirement already satisfied, skipping upgrade: notebook in /usr/local/lib/python3.5/dist-packages (from jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (6.0.1)
# Requirement already satisfied, skipping upgrade: traitlets>=4.3.1 in /usr/local/lib/python3.5/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (4.3.3)
# Requirement already satisfied, skipping upgrade: nbformat>=4.2.0 in /usr/local/lib/python3.5/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (4.4.0)
# Requirement already satisfied, skipping upgrade: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.5/dist-packages (from ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (3.5.1)
# Requirement already satisfied, skipping upgrade: decorator in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (4.4.0)
# Requirement already satisfied, skipping upgrade: jedi>=0.10 in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (0.15.1)
# Requirement already satisfied, skipping upgrade: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (2.0.10)
# Requirement already satisfied, skipping upgrade: pygments in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (2.4.2)
# Requirement already satisfied, skipping upgrade: backcall in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (0.1.0)
# Requirement already satisfied, skipping upgrade: pickleshare in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (0.7.5)
# Requirement already satisfied, skipping upgrade: pexpect; sys_platform != "win32" in /usr/local/lib/python3.5/dist-packages (from ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (4.7.0)
# Requirement already satisfied, skipping upgrade: intel-scipy in /usr/local/lib/python3.5/dist-packages (from scikit-learn<0.22,>=0.18->tensorflow-data-validation<0.16,>=0.15->tfx) (1.1.0)
# Requirement already satisfied, skipping upgrade: pydaal in /usr/local/lib/python3.5/dist-packages (from scikit-learn<0.22,>=0.18->tensorflow-data-validation<0.16,>=0.15->tfx) (2019.0.0.20180713)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.7 in /usr/local/lib/python3.5/dist-packages (from oauth2client<4,>=2.0.1->apache-beam[gcp]<3,>=2.16->tfx) (0.4.7)
# Requirement already satisfied, skipping upgrade: requests>=2.7.0 in /usr/local/lib/python3.5/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tfx) (2.22.0)
# Requirement already satisfied, skipping upgrade: docopt in ./.local/lib/python3.5/site-packages (from hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tfx) (0.6.2)
# Requirement already satisfied, skipping upgrade: pbr>=0.11 in ./.local/lib/python3.5/site-packages (from mock<3.0.0,>=1.0.1->apache-beam[gcp]<3,>=2.16->tfx) (5.4.3)
# Requirement already satisfied, skipping upgrade: google-api-core<2.0.0dev,>=1.14.0 in /usr/local/lib/python3.5/dist-packages (from google-cloud-core<2,>=0.28.1; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tfx) (1.14.3)
# Requirement already satisfied, skipping upgrade: grpc-google-iam-v1<0.13dev,>=0.12.3 in /usr/local/lib/python3.5/dist-packages (from google-cloud-pubsub<1.1.0,>=0.39.0; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tfx) (0.12.3)
# Requirement already satisfied, skipping upgrade: google-resumable-media<0.5.0dev,>=0.3.1 in /usr/local/lib/python3.5/dist-packages (from google-cloud-bigquery<1.18.0,>=1.6.0; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tfx) (0.4.1)
# Requirement already satisfied, skipping upgrade: fasteners>=0.14 in ./.local/lib/python3.5/site-packages (from google-apitools<0.5.29,>=0.5.28; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tfx) (0.15)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.5/dist-packages (from keras-applications>=1.0.8->tensorflow<3,>=1.15->tfx) (2.10.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.5/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<3,>=1.15->tfx) (0.4.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.5/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<3,>=1.15->tfx) (3.1.1)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.5/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow<3,>=1.15->tfx) (0.16.0)
# Requirement already satisfied, skipping upgrade: mkl-fft in /usr/local/lib/python3.5/dist-packages (from intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.0.6)
# Requirement already satisfied, skipping upgrade: tbb4py in /usr/local/lib/python3.5/dist-packages (from intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (2019.0)
# Requirement already satisfied, skipping upgrade: mkl in /usr/local/lib/python3.5/dist-packages (from intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (2019.0)
# Requirement already satisfied, skipping upgrade: icc-rt in /usr/local/lib/python3.5/dist-packages (from intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (2019.0)
# Requirement already satisfied, skipping upgrade: mkl-random in /usr/local/lib/python3.5/dist-packages (from intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.0.1.1)
# Requirement already satisfied, skipping upgrade: ipython-genutils in /usr/local/lib/python3.5/dist-packages (from qtconsole->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.2.0)
# Requirement already satisfied, skipping upgrade: jupyter-core in /usr/local/lib/python3.5/dist-packages (from qtconsole->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (4.6.0)
# Requirement already satisfied, skipping upgrade: jupyter-client>=4.1 in /usr/local/lib/python3.5/dist-packages (from qtconsole->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (5.3.4)
# Requirement already satisfied, skipping upgrade: tornado>=4.2 in /usr/local/lib/python3.5/dist-packages (from ipykernel->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (5.1.1)
# Requirement already satisfied, skipping upgrade: testpath in /usr/local/lib/python3.5/dist-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.4.2)
# Requirement already satisfied, skipping upgrade: defusedxml in /usr/local/lib/python3.5/dist-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.6.0)
# Requirement already satisfied, skipping upgrade: mistune<2,>=0.8.1 in /usr/local/lib/python3.5/dist-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.8.4)
# Requirement already satisfied, skipping upgrade: entrypoints>=0.2.2 in /usr/local/lib/python3.5/dist-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.3)
# Requirement already satisfied, skipping upgrade: bleach in /usr/local/lib/python3.5/dist-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (3.1.0)
# Requirement already satisfied, skipping upgrade: pandocfilters>=1.4.1 in /usr/local/lib/python3.5/dist-packages (from nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.4.2)
# Requirement already satisfied, skipping upgrade: Send2Trash in /usr/local/lib/python3.5/dist-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (1.5.0)
# Requirement already satisfied, skipping upgrade: terminado>=0.8.1 in /usr/local/lib/python3.5/dist-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.8.2)
# Requirement already satisfied, skipping upgrade: prometheus-client in /usr/local/lib/python3.5/dist-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.7.1)
# Requirement already satisfied, skipping upgrade: pyzmq>=17 in /usr/local/lib/python3.5/dist-packages (from notebook->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (18.1.0)
# Requirement already satisfied, skipping upgrade: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.5/dist-packages (from nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (3.1.1)
# Requirement already satisfied, skipping upgrade: parso>=0.5.0 in /usr/local/lib/python3.5/dist-packages (from jedi>=0.10->ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (0.5.1)
# Requirement already satisfied, skipping upgrade: wcwidth in /usr/local/lib/python3.5/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (0.1.7)
# Requirement already satisfied, skipping upgrade: ptyprocess>=0.5 in /usr/local/lib/python3.5/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5->tensorflow-data-validation<0.16,>=0.15->tfx) (0.6.0)
# Requirement already satisfied, skipping upgrade: daal==2019.* in /usr/local/lib/python3.5/dist-packages (from pydaal->scikit-learn<0.22,>=0.18->tensorflow-data-validation<0.16,>=0.15->tfx) (2019.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.5/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tfx) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.5/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tfx) (2019.9.11)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.5/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tfx) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.5/dist-packages (from requests>=2.7.0->hdfs<3.0.0,>=2.1.0->apache-beam[gcp]<3,>=2.16->tfx) (1.24.2)
# Requirement already satisfied, skipping upgrade: monotonic>=0.1 in ./.local/lib/python3.5/site-packages (from fasteners>=0.14->google-apitools<0.5.29,>=0.5.28; extra == "gcp"->apache-beam[gcp]<3,>=2.16->tfx) (1.5)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.5/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<3,>=1.15->tfx) (1.2.0)
# Requirement already satisfied, skipping upgrade: tbb==2019.* in /usr/local/lib/python3.5/dist-packages (from tbb4py->intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (2019.0)
# Requirement already satisfied, skipping upgrade: intel-openmp in /usr/local/lib/python3.5/dist-packages (from mkl->intel-numpy->scipy==1.1.0->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (2019.0)
# Requirement already satisfied, skipping upgrade: webencodings in /usr/local/lib/python3.5/dist-packages (from bleach->nbconvert->jupyter<2,>=1->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.5.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata in /usr/local/lib/python3.5/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.23)
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /usr/local/lib/python3.5/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (19.3.0)
# Requirement already satisfied, skipping upgrade: pyrsistent>=0.14.0 in /usr/local/lib/python3.5/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.15.4)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.5/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow<3,>=1.15->tfx) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.5/dist-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (0.6.0)
# Requirement already satisfied, skipping upgrade: more-itertools in /usr/local/lib/python3.5/dist-packages (from zipp>=0.5->importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7->tensorflow-model-analysis<0.16,>=0.15.2->tfx) (7.2.0)

# %%
# !pip install -U --user kfp

# %%
from __future__ import absolute_import                                                       
from __future__ import division                                                              
from __future__ import print_function                                                        
                                              
import os                                                                                    
from typing import Text              
                                                                                             
import absl                                                                                  
                                                                                             
from tfx.components.base import base_component                                               
from tfx.components.base import executor_spec
from tfx.types import component_spec                                                         
                                                                                             
from tfx.orchestration import metadata                                                       
from tfx.orchestration import pipeline                                                       
from tfx.orchestration.beam import beam_dag_runner
from tfx.orchestration.config import docker_component_config                                 
from tfx.orchestration.config import pipeline_config                                         
from tfx.orchestration.kubeflow import kubeflow_dag_runner
from tfx.orchestration.launcher import docker_component_launcher              
from tfx.orchestration.launcher import in_process_component_launcher
from tfx.orchestration.launcher import kubernetes_component_launcher

# %%
_pipeline_name = 'bigquery_pipeline'
_tfx_root = os.path.join(os.environ['HOME'], 'tfx')
_pipeline_root = os.path.join(_tfx_root, 'pipelines', _pipeline_name)
# Sqlite ML-metadata db path.
_metadata_path = os.path.join(_tfx_root, 'metadata', _pipeline_name,
                              'metadata.db')

# The rate at which to sample rows from the Chicago Taxi dataset using BigQuery.
# The full taxi dataset is > 120M record.  In the interest of resource
# savings and time, we've set the default for this example to be much smaller.
# Feel free to crank it up and process the full dataset!
_query_sample_rate = 0.001  # Generate a 0.1% random sample.

# This is the upper bound of FARM_FINGERPRINT in Bigquery (ie the max value of
# signed int64).
_max_int64 = '0x7FFFFFFFFFFFFFFF'

# The query that extracts the examples from BigQuery.  The Chicago Taxi dataset
# used for this example is a public dataset available on Google AI Platform.
# https://console.cloud.google.com/marketplace/details/city-of-chicago-public-data/chicago-taxi-trips
_query = """
         SELECT
           pickup_community_area,
           fare,
           EXTRACT(MONTH FROM trip_start_timestamp) AS trip_start_month,
           EXTRACT(HOUR FROM trip_start_timestamp) AS trip_start_hour,
           EXTRACT(DAYOFWEEK FROM trip_start_timestamp) AS trip_start_day,
           UNIX_SECONDS(trip_start_timestamp) AS trip_start_timestamp,
           pickup_latitude,
           pickup_longitude,
           dropoff_latitude,
           dropoff_longitude,
           trip_miles,
           pickup_census_tract,
           dropoff_census_tract,
           payment_type,
           company,
           trip_seconds,
           dropoff_community_area,
           tips
         FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`
         WHERE (ABS(FARM_FINGERPRINT(unique_key)) / {max_int64})
           < {query_sample_rate}""".format(
               max_int64=_max_int64, query_sample_rate=_query_sample_rate)

# %%
class BigQueryViewer(base_component.BaseComponent):

  class Spec(component_spec.ComponentSpec):
    INPUTS = {}
    OUTPUTS = {}
    PARAMETERS = {
        'query': component_spec.ExecutionParameter(type=str),
    }

  SPEC_CLASS = Spec
  EXECUTOR_SPEC = executor_spec.ExecutorContainerSpec(
      image='google/cloud-sdk:latest',
      command=['bash', '-c'],
      args=[
          'echo -e $0;'
          '[ ! -z "$GOOGLE_APPLICATION_CREDENTIALS" ] && gcloud auth activate-service-account'
          ' --key-file=$GOOGLE_APPLICATION_CREDENTIALS;'
          ' bq query --nouse_legacy_sql $0',
          '{{exec_properties.query}}',
      ])

  def __init__(self, query):
    super(BigQueryViewer, self).__init__(BigQueryViewer.SPEC_CLASS(query=query))


def _create_pipeline(pipeline_name: Text, pipeline_root: Text,
                     metadata_path: Text, query: Text) -> pipeline.Pipeline:
  bq_viewer = BigQueryViewer(query=query)

  return pipeline.Pipeline(
      pipeline_name=pipeline_name,
      pipeline_root=pipeline_root,
      components=[bq_viewer],
      enable_cache=False,
      metadata_connection_config=metadata.sqlite_metadata_connection_config(
          metadata_path),
      additional_pipeline_args={},
  )

# %%
absl.logging.set_verbosity(absl.logging.INFO)
beam_dag_runner.BeamDagRunner(
      config=pipeline_config.PipelineConfig(
          supported_launcher_classes=[
              docker_component_launcher.DockerComponentLauncher
          ],
          default_component_configs=[
              docker_component_config.DockerComponentConfig(volumes=[
                  '/usr/local/google/home/hongyes/.config/gcloud:/root/.config/gcloud'
              ])
          ])).run(
              _create_pipeline(
                  pipeline_name=_pipeline_name,
                  pipeline_root=_pipeline_root,
                  metadata_path=_metadata_path,
                  query=_query))
# Out:
# INFO:absl:Component BigQueryViewer depends on [].
# INFO:absl:Component BigQueryViewer is scheduled.
# INFO:absl:Component BigQueryViewer is running.
# INFO:absl:Running driver for BigQueryViewer
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Running executor for BigQueryViewer
# INFO:absl:Container spec: {'command': ['bash', '-c'], 'args': ['echo -e $0;[ ! -z "$GOOGLE_APPLICATION_CREDENTIALS" ] && gcloud auth activate-service-account --key-file=$GOOGLE_APPLICATION_CREDENTIALS; bq query --nouse_legacy_sql $0', '\n         SELECT\n           pickup_community_area,\n           fare,\n           EXTRACT(MONTH FROM trip_start_timestamp) AS trip_start_month,\n           EXTRACT(HOUR FROM trip_start_timestamp) AS trip_start_hour,\n           EXTRACT(DAYOFWEEK FROM trip_start_timestamp) AS trip_start_day,\n           UNIX_SECONDS(trip_start_timestamp) AS trip_start_timestamp,\n           pickup_latitude,\n           pickup_longitude,\n           dropoff_latitude,\n           dropoff_longitude,\n           trip_miles,\n           pickup_census_tract,\n           dropoff_census_tract,\n           payment_type,\n           company,\n           trip_seconds,\n           dropoff_community_area,\n           tips\n         FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips`\n         WHERE (ABS(FARM_FINGERPRINT(unique_key)) / 0x7FFFFFFFFFFFFFFF)\n           < 0.001'], 'image': 'google/cloud-sdk:latest'}
# INFO:absl:Docker config: {'user': None, 'docker_server_url': None, 'additional_run_args': {}, 'privileged': False, 'name': None, 'environment': None, 'volumes': ['/usr/local/google/home/hongyes/.config/gcloud:/root/.config/gcloud']}
# INFO:absl:Docker: SELECT pickup_community_area, fare, EXTRACT(MONTH FROM trip_start_timestamp) AS trip_start_month, EXTRACT(HOUR FROM trip_start_timestamp) AS trip_start_hour, EXTRACT(DAYOFWEEK FROM trip_start_timestamp) AS trip_start_day, UNIX_SECONDS(trip_start_timestamp) AS trip_start_timestamp, pickup_latitude, pickup_longitude, dropoff_latitude, dropoff_longitude, trip_miles, pickup_census_tract, dropoff_census_tract, payment_type, company, trip_seconds, dropoff_community_area, tips FROM `bigquery-public-data.chicago_taxi_trips.taxi_trips` WHERE (ABS(FARM_FINGERPRINT(unique_key)) / 0x7FFFFFFFFFFFFFFF) < 0.001
#
# Waiting on bqjob_r51944fec004e9f40_0000016e66971f25_1 ... (0s) Current status: DONE
#
# INFO:absl:Docker: +-----------------------+-------+------------------+-----------------+----------------+----------------------+-----------------+------------------+------------------+-------------------+------------+---------------------+----------------------+--------------+--------------------------------------+--------------+------------------------+------+
#
# INFO:absl:Docker: | pickup_community_area | fare  | trip_start_month | trip_start_hour | trip_start_day | trip_start_timestamp | pickup_latitude | pickup_longitude | dropoff_latitude | dropoff_longitude | trip_miles | pickup_census_tract | dropoff_census_tract | payment_type |               company                | trip_seconds | dropoff_community_area | tips |
#
# INFO:absl:Docker: +-----------------------+-------+------------------+-----------------+----------------+----------------------+-----------------+------------------+------------------+-------------------+------------+---------------------+----------------------+--------------+--------------------------------------+--------------+------------------------+------+
#
# INFO:absl:Docker: |                    29 | 14.25 |               12 |              13 |              6 |           1544190300 |    41.860190019 |      -87.7172201 |     41.878865584 |     -87.625192142 |        4.4 |                NULL |                 NULL | Unknown      | Taxi Affiliation Services            |         1200 |                     32 |  0.0 |
#
# INFO:absl:Docker: |                    41 |  11.0 |               12 |              20 |              7 |           1544904900 |    41.794090253 |    -87.592310855 |     41.794090253 |     -87.592310855 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1260 |                     41 |  0.0 |
#
# INFO:absl:Docker: |                    41 | 22.75 |               12 |              17 |              1 |           1545585300 |    41.794090253 |    -87.592310855 |     41.899602111 |     -87.633308037 |        8.2 |                NULL |                 NULL | Credit Card  | Star North Management LLC            |         1140 |                      8 |  6.0 |
#
# INFO:absl:Docker: |                    41 |  5.75 |               12 |              11 |              1 |           1545565500 |    41.794090253 |    -87.592310855 |     41.808916283 |     -87.596183344 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          240 |                     39 |  0.0 |
#
# INFO:absl:Docker: |                    41 |  28.5 |               12 |              23 |              1 |           1545001200 |    41.794090253 |    -87.592310855 |     41.944226601 |     -87.655998182 |       11.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1020 |                      6 |  0.0 |
#
# INFO:absl:Docker: |                     7 |  10.0 |               12 |               7 |              2 |           1543822200 |    41.922082541 |    -87.634156093 |     41.880994471 |     -87.632746489 |        0.1 |         17031071400 |          17031839100 | Credit Card  | Taxi Affiliation Services            |          600 |                     32 |  2.0 |
#
# INFO:absl:Docker: |                     7 |   6.0 |               11 |              22 |              3 |           1543356900 |    41.922082541 |    -87.634156093 |     41.907520075 |       -87.6266589 |        1.1 |         17031071400 |          17031080100 | Credit Card  | Taxi Affiliation Services            |          300 |                      8 |  2.0 |
#
# INFO:absl:Docker: |                    31 |   7.0 |               12 |               5 |              7 |           1543643100 |    41.850266366 |    -87.667569312 |     41.850266366 |     -87.667569312 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          540 |                     31 |  0.0 |
#
# INFO:absl:Docker: |                     2 | 10.75 |               12 |              11 |              6 |           1545392700 |    42.001571027 |    -87.695012589 |      41.96581197 |     -87.655878786 |        2.9 |                NULL |                 NULL | Credit Card  | Taxi Affiliation Services            |          660 |                      3 | 2.15 |
#
# INFO:absl:Docker: |                     2 |   6.5 |               12 |              20 |              1 |           1544385600 |    42.001571027 |    -87.695012589 |     42.001571027 |     -87.695012589 |        1.3 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          360 |                      2 |  0.0 |
#
# INFO:absl:Docker: |                     2 | 18.75 |               11 |               4 |              6 |           1543553100 |    42.001571027 |    -87.695012589 |       41.9867118 |     -87.663416405 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1380 |                     77 |  0.0 |
#
# INFO:absl:Docker: |                    64 |  15.0 |               12 |              11 |              7 |           1545477300 |    41.779582888 |    -87.768510849 |      41.79259236 |     -87.769615453 |        4.1 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1080 |                     56 |  0.0 |
#
# INFO:absl:Docker: |                    11 |  13.5 |               12 |              18 |              7 |           1545501600 |    41.978829526 |    -87.771166703 |             NULL |              NULL |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1080 |                   NULL |  0.0 |
#
# INFO:absl:Docker: |                    11 |  20.5 |               12 |              23 |              1 |           1544397300 |    41.978829526 |    -87.771166703 |     41.980264315 |     -87.913624596 |        7.1 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          780 |                     76 |  0.0 |
#
# INFO:absl:Docker: |                    43 | 13.75 |               12 |              19 |              4 |           1545853500 |    41.761577908 |    -87.572781987 |     41.761577908 |     -87.572781987 |        0.2 |                NULL |                 NULL | Unknown      | Taxi Affiliation Services            |         1080 |                     43 |  0.0 |
#
# INFO:absl:Docker: |                    41 | 23.25 |               12 |              13 |              3 |           1545139800 |    41.790506261 |    -87.583143717 |     41.885300022 |     -87.642808466 |        7.8 |         17031411000 |          17031280100 | Cash         | Taxi Affiliation Services            |         1320 |                     28 |  0.0 |
#
# INFO:absl:Docker: |                    42 |   4.0 |               11 |              13 |              3 |           1543323600 |     41.77887686 |    -87.594925439 |      41.77887686 |     -87.594925439 |        0.2 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          120 |                     42 |  0.0 |
#
# INFO:absl:Docker: |                    39 |   6.5 |               12 |              16 |              3 |           1544544900 |    41.808916283 |    -87.596183344 |     41.812948939 |     -87.617859676 |        1.4 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          300 |                     38 |  0.0 |
#
# INFO:absl:Docker: |                    39 | 15.75 |               11 |               7 |              2 |           1543218300 |    41.808916283 |    -87.596183344 |      41.80901825 |     -87.659166599 |        4.8 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1260 |                     61 |  0.0 |
#
# INFO:absl:Docker: |                    35 |  3.25 |               11 |              11 |              7 |           1543059900 |    41.841691119 |    -87.612563947 |     41.841691119 |     -87.612563947 |        0.0 |         17031350100 |          17031350100 | Cash         | Taxi Affiliation Services            |            0 |                     35 |  0.0 |
#
# INFO:absl:Docker: |                    38 |   7.0 |               12 |               7 |              3 |           1545117300 |    41.812948939 |    -87.617859676 |     41.794090253 |     -87.592310855 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          360 |                     41 |  0.0 |
#
# INFO:absl:Docker: |                    35 |  3.25 |               12 |              14 |              2 |           1545660000 |    41.835117986 |    -87.618677767 |     41.835117986 |     -87.618677767 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |            0 |                     35 |  0.0 |
#
# INFO:absl:Docker: |                    35 |  12.0 |               11 |               8 |              6 |           1542961800 |    41.835117986 |    -87.618677767 |     41.878865584 |     -87.625192142 |        0.2 |                NULL |                 NULL | Credit Card  | Taxi Affiliation Services            |          780 |                     32 |  2.4 |
#
# INFO:absl:Docker: |                    33 |  26.0 |               11 |              17 |              1 |           1543167000 |    41.857183858 |    -87.620334624 |     41.944226601 |     -87.655998182 |        9.3 |                NULL |                 NULL | Credit Card  | Taxi Affiliation Services            |         1560 |                      6 |  5.2 |
#
# INFO:absl:Docker: |                     8 |  37.0 |               12 |              18 |              1 |           1544381100 |    41.905857769 |    -87.630865027 |     41.785998518 |     -87.750934289 |       14.1 |         17031080202 |          17031980100 | Credit Card  | Taxi Affiliation Services            |         1920 |                     56 |  7.4 |
#
# INFO:absl:Docker: |                     8 |  8.75 |               11 |               9 |              6 |           1543568400 |    41.905857769 |    -87.630865027 |     41.884987192 |     -87.620992913 |        2.0 |         17031080202 |          17031320100 | Credit Card  | Taxi Affiliation Services            |          600 |                     32 |  1.0 |
#
# INFO:absl:Docker: |                     7 | 13.25 |               12 |              18 |              7 |           1544898600 |    41.921854911 |    -87.646210977 |     41.892507781 |     -87.626214906 |        0.1 |         17031071200 |          17031081500 | Cash         | Taxi Affiliation Services            |         1260 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     7 |   9.5 |               12 |              23 |              5 |           1544742000 |    41.921854911 |    -87.646210977 |     41.892072635 |     -87.628874157 |        2.3 |         17031071200 |          17031081600 | Credit Card  | Taxi Affiliation Services            |          600 |                      8 |  2.0 |
#
# INFO:absl:Docker: |                     7 |  11.5 |               12 |              20 |              6 |           1544820300 |    41.921854911 |    -87.646210977 |      41.89321636 |      -87.63784421 |        2.7 |         17031071200 |          17031081800 | Credit Card  | Choice Taxi Association              |          900 |                      8 | 2.85 |
#
# INFO:absl:Docker: |                     7 | 39.75 |               12 |              13 |              6 |           1544187600 |    41.929077655 |    -87.646293476 |      41.97907082 |     -87.903039661 |        0.0 |         17031070200 |          17031980000 | Cash         | Blue Ribbon Taxi Association Inc.    |         2100 |                     76 |  0.0 |
#
# INFO:absl:Docker: |                     6 |   9.5 |               11 |              19 |              7 |           1543087800 |    41.936310131 |    -87.651562592 |     41.914616286 |     -87.631717366 |        0.0 |         17031063000 |          17031071500 | Cash         | Blue Ribbon Taxi Association Inc.    |          720 |                      7 |  0.0 |
#
# INFO:absl:Docker: |                     6 |  13.5 |                1 |               2 |              3 |           1546310700 |    41.942691844 |    -87.651770507 |     41.898331794 |     -87.620762865 |        0.2 |         17031062100 |          17031081300 | Credit Card  | Blue Ribbon Taxi Association Inc.    |          780 |                      8 |  2.0 |
#
# INFO:absl:Docker: |                    71 | 11.25 |               12 |              11 |              1 |           1546167600 |    41.744205146 |    -87.656305986 |     41.744205146 |     -87.656305986 |        0.0 |                NULL |                 NULL | Cash         | Blue Ribbon Taxi Association Inc.    |         1260 |                     71 |  0.0 |
#
# INFO:absl:Docker: |                    67 |  21.0 |               11 |               9 |              1 |           1542531600 |    41.775928827 |    -87.666596265 |     41.808916283 |     -87.596183344 |        7.4 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          960 |                     39 |  0.0 |
#
# INFO:absl:Docker: |                    24 |  12.0 |               12 |               1 |              1 |           1544319900 |    41.908378669 |    -87.670945075 |      41.89321636 |      -87.63784421 |        0.0 |         17031241500 |          17031081800 | Cash         | Blue Ribbon Taxi Association Inc.    |          600 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                    28 |  7.25 |               12 |              23 |              5 |           1545951600 |     41.87866742 |    -87.671653621 |     41.885300022 |     -87.642808466 |        1.6 |         17031838100 |          17031280100 | Cash         | KOAM Taxi Association                |          420 |                     28 |  0.0 |
#
# INFO:absl:Docker: |                     1 |   8.5 |               12 |               3 |              7 |           1544240700 |    42.001698194 |    -87.673574032 |     42.009018227 |     -87.672723959 |        0.0 |         17031830600 |          17031010702 | Cash         | Blue Ribbon Taxi Association Inc.    |          420 |                      1 |  0.0 |
#
# INFO:absl:Docker: |                    59 |  3.25 |               12 |              14 |              5 |           1544710500 |    41.833517886 |    -87.681355829 |     41.833517886 |     -87.681355829 |        0.0 |         17031840300 |          17031840300 | Cash         | Taxi Affiliation Services            |            0 |                     59 |  0.0 |
#
# INFO:absl:Docker: |                     5 |  7.25 |               12 |               6 |              2 |           1544421600 |    41.947791586 |    -87.683834942 |      41.96581197 |     -87.655878786 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          300 |                      3 |  0.0 |
#
# INFO:absl:Docker: |                     5 |  19.0 |               12 |              12 |              2 |           1546260300 |    41.947791586 |    -87.683834942 |     41.899602111 |     -87.633308037 |        6.1 |                NULL |                 NULL | Dispute      | Taxicab Insurance Agency, LLC        |         1140 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     5 |   3.5 |               12 |              15 |              1 |           1546183800 |    41.947791586 |    -87.683834942 |     41.947791586 |     -87.683834942 |        0.2 |                NULL |                 NULL | Credit Card  | Star North Management LLC            |            0 |                      5 |  0.0 |
#
# INFO:absl:Docker: |                     5 |   8.0 |               12 |              14 |              7 |           1544882400 |    41.947791586 |    -87.683834942 |     41.975170943 |     -87.687515515 |        0.1 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          480 |                      4 |  0.0 |
#
# INFO:absl:Docker: |                    58 |  6.75 |               12 |               2 |              4 |           1545789600 |    41.817366208 |    -87.698860797 |     41.817366208 |     -87.698860797 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          480 |                     58 |  0.0 |
#
# INFO:absl:Docker: |                    16 |  27.5 |               12 |               7 |              3 |           1545723000 |    41.953582125 |     -87.72345239 |     41.980264315 |     -87.913624596 |        0.6 |                NULL |                 NULL | Credit Card  | Taxi Affiliation Services            |          960 |                     76 |  0.0 |
#
# INFO:absl:Docker: |                    16 |  12.5 |               12 |              14 |              5 |           1544710500 |    41.953582125 |     -87.72345239 |     41.944226601 |     -87.655998182 |        3.5 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          960 |                      6 |  0.0 |
#
# INFO:absl:Docker: |                    15 |  3.25 |                1 |               9 |              7 |           1547285400 |    41.954027649 |    -87.763399032 |     41.954027649 |     -87.763399032 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |           60 |                     15 |  0.0 |
#
# INFO:absl:Docker: |                    56 |  28.0 |               12 |               0 |              2 |           1543796100 |     41.79259236 |    -87.769615453 |             NULL |              NULL |        0.0 |                NULL |                 NULL | Credit Card  | Star North Management LLC            |         1620 |                   NULL |  6.6 |
#
# INFO:absl:Docker: |                    56 |  40.5 |               12 |              13 |              2 |           1546263900 |     41.79259236 |    -87.769615453 |     41.944226601 |     -87.655998182 |       16.1 |                NULL |                 NULL | Credit Card  | Taxi Affiliation Services            |         1680 |                      6 |  8.9 |
#
# INFO:absl:Docker: |                    10 |  6.25 |               12 |              21 |              1 |           1544391000 |    41.985015101 |    -87.804532006 |     41.985015101 |     -87.804532006 |        1.2 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          240 |                     10 |  0.0 |
#
# INFO:absl:Docker: |                     8 | 11.75 |               11 |               9 |              6 |           1543569300 |    41.907520075 |      -87.6266589 |     41.879255084 |     -87.642648998 |        0.1 |         17031080100 |          17031281900 | Credit Card  | Taxi Affiliation Services            |         1200 |                     28 | 2.35 |
#
# INFO:absl:Docker: |                     8 |  6.75 |               12 |              12 |              6 |           1544184900 |    41.907520075 |      -87.6266589 |     41.892072635 |     -87.628874157 |        0.0 |         17031080100 |          17031081600 | Cash         | Blue Ribbon Taxi Association Inc.    |          420 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     8 |   9.0 |               12 |              10 |              3 |           1544522400 |    41.907520075 |      -87.6266589 |     41.880994471 |     -87.632746489 |        1.9 |         17031080100 |          17031839100 | Credit Card  | Taxi Affiliation Services            |          720 |                     32 |  2.0 |
#
# INFO:absl:Docker: |                     1 |  6.25 |               11 |               6 |              1 |           1542523500 |    42.009622881 |    -87.670166857 |       41.9867118 |     -87.663416405 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          180 |                     77 |  0.0 |
#
# INFO:absl:Docker: |                     4 |  8.25 |               12 |              11 |              3 |           1545133500 |    41.975170943 |    -87.687515515 |       41.9867118 |     -87.663416405 |        2.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          540 |                     77 |  0.0 |
#
# INFO:absl:Docker: |                     4 | 11.75 |               12 |               3 |              2 |           1544412600 |    41.975170943 |    -87.687515515 |     41.953582125 |      -87.72345239 |        0.1 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |         1140 |                     16 |  0.0 |
#
# INFO:absl:Docker: |                     4 |  3.25 |               11 |              15 |              6 |           1543592700 |    41.975170943 |    -87.687515515 |     41.975170943 |     -87.687515515 |        0.0 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |            0 |                      4 |  0.0 |
#
# INFO:absl:Docker: |                    21 | 12.25 |               12 |               6 |              1 |           1545544800 |    41.938666196 |    -87.711210593 |     41.890608853 |     -87.756046711 |        0.2 |                NULL |                 NULL | Cash         | Taxi Affiliation Services            |          780 |                     25 |  0.0 |
#
# INFO:absl:Docker: |                     8 | 10.75 |               11 |              20 |              6 |           1479500100 |    41.909495669 |    -87.630963601 |     41.879255084 |     -87.642648998 |        2.5 |         17031080201 |          17031281900 | Cash         | Sun Taxi                             |          900 |                     28 |  0.0 |
#
# INFO:absl:Docker: |                     8 |   7.5 |               11 |              10 |              2 |           1479724200 |    41.909495669 |    -87.630963601 |      41.89503345 |     -87.619710672 |        1.3 |         17031080201 |          17031081401 | Credit Card  | Medallion Leasin                     |          480 |                      8 |  1.0 |
#
# INFO:absl:Docker: |                     7 |  11.0 |               11 |              17 |              2 |           1479142800 |    41.922082541 |    -87.634156093 |     41.962178629 |     -87.645378762 |       3.29 |         17031071400 |          17031031400 | Credit Card  | Checker Taxi Affiliation             |          600 |                      3 |  2.0 |
#
# INFO:absl:Docker: |                     7 |  9.75 |               12 |              20 |              7 |           1480797900 |    41.922082541 |    -87.634156093 |     41.892507781 |     -87.626214906 |       2.13 |         17031071400 |          17031081500 | Cash         | Chicago Carriage Cab Corp            |          804 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     6 | 18.75 |               11 |              15 |              5 |           1479394800 |    41.943155086 |    -87.640698076 |     41.880994471 |     -87.632746489 |        5.7 |         17031061902 |          17031839100 | Credit Card  | City Service                         |         1200 |                     32 | 4.68 |
#
# INFO:absl:Docker: |                     3 |  12.0 |               11 |              13 |              4 |           1478696400 |    41.962178629 |    -87.645378762 |     41.907520075 |       -87.6266589 |       3.71 |         17031031400 |          17031080100 | Cash         | City Service                         |          425 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     6 |  16.0 |               12 |              22 |              5 |           1480632300 |    41.938232293 |    -87.646782081 |     41.892507781 |     -87.626214906 |        5.4 |         17031063100 |          17031081500 | Credit Card  | Medallion Leasin                     |          660 |                      8 |  3.4 |
#
# INFO:absl:Docker: |                    28 |  6.25 |               12 |              17 |              6 |           1481303700 |    41.879066994 |    -87.657005027 |     41.885300022 |     -87.642808466 |        0.9 |         17031833100 |          17031280100 | Credit Card  | Checker Taxi Affiliation             |          480 |                     28 |  2.0 |
#
# INFO:absl:Docker: |                    24 |  11.0 |               12 |               0 |              6 |           1480636800 |    41.906025969 |    -87.675311622 |     41.892507781 |     -87.626214906 |        3.3 |         17031241400 |          17031081500 | Cash         | Chicago Taxicab                      |          480 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                    24 | 17.25 |               11 |               1 |              1 |           1479603600 |    41.906025969 |    -87.675311622 |      41.93057857 |     -87.642206313 |        5.0 |         17031241400 |          17031070102 | Credit Card  | Chicago Carriage Cab Corp            |         1443 |                      7 | 3.75 |
#
# INFO:absl:Docker: |                     2 | 30.25 |               11 |              11 |              3 |           1479815100 |    42.001571027 |    -87.695012589 |     41.980264315 |     -87.913624596 |      11.57 |                NULL |                 NULL | Cash         | Taxi Affiliation Service Yellow      |         1440 |                     76 |  0.0 |
#
# INFO:absl:Docker: |                     2 |   8.0 |               11 |              10 |              5 |           1479981600 |    42.001571027 |    -87.695012589 |       41.9867118 |     -87.663416405 |       2.18 |                NULL |                 NULL | Cash         | Patriot Taxi Dba Peace Taxi Associat |          480 |                     77 |  0.0 |
#
# INFO:absl:Docker: |                    33 |  23.0 |               11 |              12 |              2 |           1478520000 |    41.857183858 |    -87.620334624 |      41.79259236 |     -87.769615453 |       9.02 |                NULL |                 NULL | Credit Card  | Chicago Carriage Cab Corp            |         1055 |                     56 | 7.12 |
#
# INFO:absl:Docker: |                    35 |  25.0 |               11 |              15 |              6 |           1479482100 |     41.84201118 |    -87.622036461 |      41.84201118 |     -87.622036461 |        0.0 |         17031839200 |          17031839200 | Prcard       | Chicago Carriage Cab Corp            |           21 |                     35 |  2.0 |
#
# INFO:absl:Docker: |                    35 |  3.25 |               11 |              11 |              7 |           1479555000 |     41.84201118 |    -87.622036461 |      41.84201118 |     -87.622036461 |        0.0 |         17031839200 |          17031839200 | Cash         | Chicago Carriage Cab Corp            |           20 |                     35 |  0.0 |
#
# INFO:absl:Docker: |                     8 |   9.5 |               11 |               2 |              5 |           1479952800 |    41.905857769 |    -87.630865027 |     41.906025969 |     -87.675311622 |       2.63 |         17031080202 |          17031241400 | Credit Card  | Chicago Carriage Cab Corp            |          458 |                     24 |  2.0 |
#
# INFO:absl:Docker: |                     8 | 14.75 |               12 |              18 |              7 |           1480788000 |    41.905857769 |    -87.630865027 |     41.870607372 |     -87.622172937 |       4.25 |         17031080202 |          17031320600 | Cash         | Taxi Affiliation Service Yellow      |         1020 |                     32 |  0.0 |
#
# INFO:absl:Docker: |                     8 |  13.0 |               11 |               3 |              1 |           1480218300 |    41.905857769 |    -87.630865027 |     41.892507781 |     -87.626214906 |        4.0 |         17031080202 |          17031081500 | Cash         | City Service                         |          600 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     8 |   6.5 |               11 |               2 |              1 |           1479609000 |    41.905857769 |    -87.630865027 |     41.914616286 |     -87.631717366 |       1.12 |         17031080202 |          17031071500 | Credit Card  | Chicago Carriage Cab Corp            |          417 |                      7 |  2.0 |
#
# INFO:absl:Docker: |                     8 | 12.75 |               12 |              19 |              6 |           1480707000 |    41.905857769 |    -87.630865027 |     41.911972301 |     -87.683642922 |       3.34 |         17031080202 |          17031240500 | Cash         | Patriot Taxi Dba Peace Taxi Associat |         1020 |                     24 |  0.0 |
#
# INFO:absl:Docker: |                    34 |  3.25 |               11 |              16 |              2 |           1480348800 |    41.851017824 |    -87.635091856 |     41.851017824 |     -87.635091856 |        0.0 |         17031841100 |          17031841100 | Cash         | Chicago Independents                 |            0 |                     34 |  0.0 |
#
# INFO:absl:Docker: |                     7 |  6.75 |               12 |              22 |              7 |           1480805100 |     41.92926299 |    -87.635890954 |     41.936310131 |     -87.651562592 |        1.1 |         17031070101 |          17031063000 | Cash         | Globe Taxi                           |          480 |                      6 |  0.0 |
#
# INFO:absl:Docker: |                     8 |  3.25 |               11 |              17 |              7 |           1480181400 |    41.907412816 |    -87.640901525 |     41.907412816 |     -87.640901525 |        0.0 |         17031080400 |          17031080400 | Cash         | City Service                         |            0 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                    28 | 10.25 |               11 |              17 |              2 |           1478540700 |    41.867902418 |    -87.642958665 |     41.859349715 |     -87.617358006 |        2.6 |         17031841900 |          17031330100 | Cash         | City Service                         |          660 |                     33 |  0.0 |
#
# INFO:absl:Docker: |                    28 |   3.5 |               11 |               0 |              1 |           1478997900 |    41.867902418 |    -87.642958665 |     41.867902418 |     -87.642958665 |        0.0 |         17031841900 |          17031841900 | Cash         | Chicago Carriage Cab Corp            |           81 |                     28 |  0.0 |
#
# INFO:absl:Docker: |                    60 |  3.25 |               11 |              18 |              7 |           1479580200 |    41.836150155 |    -87.648787952 |     41.836150155 |     -87.648787952 |        0.0 |                NULL |                 NULL | Credit Card  | Taxi Affiliation Service Yellow      |            0 |                     60 |  0.0 |
#
# INFO:absl:Docker: |                     8 |   8.0 |               11 |              20 |              3 |           1479240000 |    41.904935302 |    -87.649907226 |     41.906025969 |     -87.675311622 |        1.9 |         17031842200 |          17031241400 | Credit Card  | Globe Taxi                           |          480 |                     24 |  2.0 |
#
# INFO:absl:Docker: |                     8 |   8.0 |               12 |              17 |              5 |           1480611600 |    41.904935302 |    -87.649907226 |     41.890922026 |     -87.618868355 |        1.4 |         17031842200 |          17031081403 | Cash         | Medallion Leasin                     |          660 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     8 |  10.5 |               11 |              18 |              2 |           1478544300 |    41.904935302 |    -87.649907226 |     41.898331794 |     -87.620762865 |        2.7 |         17031842200 |          17031081300 | Cash         | City Service                         |          660 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     8 |   8.5 |               11 |              13 |              5 |           1478785500 |    41.904935302 |    -87.649907226 |     41.892507781 |     -87.626214906 |        1.7 |         17031842200 |          17031081500 | Credit Card  | Sun Taxi                             |          600 |                      8 |  2.0 |
#
# INFO:absl:Docker: |                     8 |  6.75 |               12 |               9 |              6 |           1480669200 |    41.904935302 |    -87.649907226 |     41.900221297 |     -87.629105186 |        1.0 |         17031842200 |          17031081100 | Cash         | Service Taxi Association             |          420 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     8 | 10.25 |               12 |               0 |              1 |           1480809600 |    41.904935302 |    -87.649907226 |     41.905857769 |     -87.630865027 |       1.89 |         17031842200 |          17031080202 | Credit Card  | Patriot Taxi Dba Peace Taxi Associat |          900 |                      8 |  3.0 |
#
# INFO:absl:Docker: |                     8 |  5.75 |               11 |              11 |              5 |           1479383100 |    41.904935302 |    -87.649907226 |     41.892042136 |      -87.63186395 |        0.8 |         17031842200 |          17031081700 | Credit Card  | Sun Taxi                             |          300 |                      8 |  2.0 |
#
# INFO:absl:Docker: |                     8 |  3.25 |               11 |               1 |              6 |           1479433500 |    41.904935302 |    -87.649907226 |     41.904935302 |     -87.649907226 |        0.0 |         17031842200 |          17031842200 | Credit Card  | Chicago Carriage Cab Corp            |           10 |                      8 |  1.0 |
#
# INFO:absl:Docker: |                     8 | 41.25 |               11 |              18 |              2 |           1478543400 |    41.904935302 |    -87.649907226 |      41.97907082 |     -87.903039661 |      16.46 |         17031842200 |          17031980000 | Cash         | Patriot Taxi Dba Peace Taxi Associat |         2100 |                     76 |  0.0 |
#
# INFO:absl:Docker: |                     3 | 16.25 |               11 |               1 |              7 |           1479519000 |    41.972929317 |    -87.650290074 |     41.898331794 |     -87.620762865 |       5.73 |         17031031300 |          17031081300 | Cash         | Chicago Carriage Cab Corp            |          600 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     7 | 12.75 |               11 |               3 |              1 |           1478402100 |    41.921778188 |    -87.651061884 |     41.935983574 |     -87.675821928 |       3.48 |         17031071100 |          17031051300 | Credit Card  | Chicago Carriage Cab Corp            |          904 |                      5 | 0.75 |
#
# INFO:absl:Docker: |                     7 |  12.0 |               11 |              23 |              4 |           1480549500 |    41.929046937 |    -87.651310877 |     41.892507781 |     -87.626214906 |       3.65 |         17031070300 |          17031081500 | Cash         | Nova Taxi Affiliation Llc            |          599 |                      8 |  0.0 |
#
# INFO:absl:Docker: |                     7 |   5.5 |               12 |               2 |              7 |           1480730400 |    41.929046937 |    -87.651310877 |     41.914747305 |     -87.654007029 |        0.9 |         17031070300 |          17031832600 | Cash         | Medallion Leasin                     |          300 |                      7 |  0.0 |
#
# INFO:absl:Docker: |                     6 |  7.25 |               11 |              22 |              7 |           1478990700 |    41.942691844 |    -87.651770507 |     41.921778188 |     -87.651061884 |       1.45 |         17031062100 |          17031071100 | Credit Card  | Chicago Carriage Cab Corp            |          507 |                      7 |  3.0 |
#
# INFO:absl:Docker: |                    24 |   7.0 |               11 |               8 |              4 |           1480494600 |    41.892658108 |    -87.652534484 |      41.89321636 |      -87.63784421 |       1.36 |         17031243500 |          17031081800 | Credit Card  | Chicago Carriage Cab Corp            |          438 |                      8 |  2.0 |
#
# INFO:absl:Docker: |                    24 |  3.25 |               12 |              12 |              6 |           1480680900 |     41.89830587 |    -87.653613982 |      41.89830587 |     -87.653613982 |        0.0 |         17031842300 |          17031842300 | Cash         | Checker Taxi Affiliation             |            0 |                     24 |  0.0 |
#
# INFO:absl:Docker: |                    24 |  3.25 |               12 |              19 |              2 |           1480966200 |     41.89830587 |    -87.653613982 |      41.89830587 |     -87.653613982 |        0.0 |         17031842300 |          17031842300 | Cash         | Taxi Affiliation Service Yellow      |            0 |                     24 |  0.0 |
#
# INFO:absl:Docker: +-----------------------+-------+------------------+-----------------+----------------+----------------------+-----------------+------------------+------------------+-------------------+------------+---------------------+----------------------+--------------+--------------------------------------+--------------+------------------------+------+
#
# INFO:absl:Running publisher for BigQueryViewer
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Component BigQueryViewer is finished.

# %%
from kubernetes import client
def use_gcp_secret():
  secret_name = 'user-gcp-sa'
  secret_volume_mount_path = '/secret/gcp-credentials'
  secret_file_path_in_volume = '/' + secret_name + '.json'
  volume_name = 'gcp-credentials-' + secret_name
  volumes = [
      client.V1Volume(
          name=volume_name,
          secret=client.V1SecretVolumeSource(secret_name=secret_name))
  ]
  containers = [
      client.V1Container(
          name='main',
          volume_mounts=[
              client.V1VolumeMount(
                  name=volume_name,
                  mount_path=secret_volume_mount_path,
              )
          ],
          env=[
              client.V1EnvVar(
                  name='GOOGLE_APPLICATION_CREDENTIALS',
                  value=secret_volume_mount_path + secret_file_path_in_volume,
              ),
              client.V1EnvVar(
                  name='CLOUDSDK_AUTH_CREDENTIAL_FILE_OVERRIDE',
                  value=secret_volume_mount_path + secret_file_path_in_volume,
              )
          ])
  ]

  return client.V1Pod(
      spec=client.V1PodSpec(containers=containers, volumes=volumes))

# %%
from tfx.orchestration.config import kubernetes_component_config

metadata_config = kubeflow_dag_runner.get_default_kubeflow_metadata_config()
# This pipeline automatically injects the Kubeflow TFX image if the
# environment variable 'KUBEFLOW_TFX_IMAGE' is defined. Currently, the tfx
# cli tool exports the environment variable to pass to the pipelines.
tfx_image = os.environ.get('KUBEFLOW_TFX_IMAGE', None)
k8s_config = kubernetes_component_config.KubernetesComponentConfig(
      use_gcp_secret())
runner_config = kubeflow_dag_runner.KubeflowDagRunnerConfig(
  kubeflow_metadata_config=metadata_config,
  # Specify custom docker image to use.
  tfx_image=tfx_image,
  supported_launcher_classes=[
      in_process_component_launcher.InProcessComponentLauncher,
      kubernetes_component_launcher.KubernetesComponentLauncher,
  ],
  default_component_configs=[k8s_config])
kubeflow_dag_runner.KubeflowDagRunner(config=runner_config).run(
  _create_pipeline(
      pipeline_name=_pipeline_name,
      pipeline_root=_pipeline_root,
      metadata_path=_metadata_path,
      query=_query))
# Out:
# INFO:absl:Adding upstream dependencies for component BigQueryViewer

# %%
import kfp
client = kfp.Client(host='36a59b5371d6ab2-dot-us-west1.notebooks.googleusercontent.com')

# %%
client.create_run_from_pipeline_package(pipeline_file='bigquery_pipeline.tar.gz', arguments={})
# Out:
# Experiment link <a href="http://36a59b5371d6ab2-dot-us-west1.notebooks.googleusercontent.com/#/experiments/details/1854cb3d-1ca7-4d01-ae26-51fbe3153cff" target="_blank" >here</a>
# Run link <a href="http://36a59b5371d6ab2-dot-us-west1.notebooks.googleusercontent.com/#/runs/details/8edae657-262c-4dcd-bbb9-b60821645604" target="_blank" >here</a>
# RunPipelineResult(run_id=8edae657-262c-4dcd-bbb9-b60821645604)
